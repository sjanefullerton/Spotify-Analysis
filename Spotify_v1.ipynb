# %% [markdown]
# # Spotify

# %% [markdown]
# Your task is to analyse the data given to you and explore predictive tasks that could provide the company with insight on some burning questions such as:
#
# 1. What drives cross-regional popularity of music; is it the artist, or something about the song?(explore if artists from certain parts of the world tend to be more popular worldwide)
# 2. Can we figure out which artists or genres are going to be popular in 2024 given the historic data from 2017?
# 3. Does the popularity of a track in one region predict its (upcoming?) popularity in other regions?
# 4. Are there any patterns in what day(s) of the week and/or months experience the most streams?

# %% [markdown]
# 1. Who are the most popular artists (say top 10)?
# 2. Who was the most popular each month?
# 3. Name the songs people dance to the most?
# 4. Is there a relationship between danceability and energy or loundness of the music?
# 5. Does a total number of artists affect the popularity of a song?
# 5. If it does, then can we predict if more artists would make a song more popular
# 6. How does valency affect the popularity of a song. (A high valence song is about happiness, excitement and joy, whereas a low valence song is about sadness, anger or depression.
# 7. Check the mean value of audio features of top 10 songs. Can we predict popularity of songs if they have greater value than the mean value for those features?
#
#
# 1. EDA for each feature
# 2. Release date and popularity date

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r'~/anaconda3/Anjali-Spotify/Spotify_Dataset_V3.csv',sep=';')

# %%
data.head()
# Out:
#    Rank            Title                     Artists        Date  \
# 0     1  Ella Baila Sola  Eslabon Armado, Peso Pluma  29/05/2023
# 1     1  Ella Baila Sola  Eslabon Armado, Peso Pluma  29/05/2023
# 2     2   WHERE SHE GOES                   Bad Bunny  29/05/2023
# 3     3  La Bebe - Remix       Yng Lvcas, Peso Pluma  29/05/2023
# 4     3  La Bebe - Remix       Yng Lvcas, Peso Pluma  29/05/2023
#
#    Danceability  Energy  Loudness  Speechiness  Acousticness  \
# 0         0.668   0.758   -5176.0        0.033         0.483
# 1         0.668   0.758   -5176.0        0.033         0.483
# 2         0.652   0.800   -4019.0        0.061         0.143
# 3         0.812   0.479   -5678.0        0.333         0.213
# 4         0.812   0.479   -5678.0        0.333         0.213
#
#    Instrumentalness  Valence # of Artist   Artist (Ind.) # of Nationality  \
# 0             0.000    0.834    Artist 1  Eslabon Armado    Nationality 1
# 1             0.000    0.834    Artist 2      Peso Pluma    Nationality 2
# 2             0.629    0.234    Artist 1       Bad Bunny    Nationality 1
# 3             0.000    0.559    Artist 1       Yng Lvcas    Nationality 1
# 4             0.000    0.559    Artist 2      Peso Pluma    Nationality 2
#
#    Nationality      Continent  Points (Total)  \
# 0       Mexico  Latin-America             200
# 1       Mexico  Latin-America             200
# 2  Puerto Rico  Latin-America             199
# 3       Mexico  Latin-America             198
# 4       Mexico  Latin-America             198
#
#    Points (Ind for each Artist/Nat)                      id  \
# 0                             100.0  3qQbCzHBycnDpGskqOWY0E
# 1                             100.0  3qQbCzHBycnDpGskqOWY0E
# 2                             199.0  7ro0hRteUMfnOioTFI5TG1
# 3                              99.0  2UW7JaomAMuX9pZrjVpHAU
# 4                              99.0  2UW7JaomAMuX9pZrjVpHAU
#
#                                             Song URL
# 0  https://open.spotify.com/track/3qQbCzHBycnDpGs...
# 1  https://open.spotify.com/track/3qQbCzHBycnDpGs...
# 2  https://open.spotify.com/track/7ro0hRteUMfnOio...
# 3  https://open.spotify.com/track/2UW7JaomAMuX9pZ...
# 4  https://open.spotify.com/track/2UW7JaomAMuX9pZ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 651936 entries, 0 to 651935
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Rank                              651936 non-null  int64
#  1   Title                             651936 non-null  object
#  2   Artists                           651936 non-null  object
#  3   Date                              651936 non-null  object
#  4   Danceability                      651936 non-null  float64
#  5   Energy                            651936 non-null  float64
#  6   Loudness                          651936 non-null  float64
#  7   Speechiness                       651936 non-null  float64
#  8   Acousticness                      651936 non-null  float64
#  9   Instrumentalness                  651936 non-null  float64
#  10  Valence                           651936 non-null  float64
#  11  # of Artist                       651936 non-null  object
#  12  Artist (Ind.)                     651936 non-null  object
#  13  # of Nationality                  651936 non-null  object
#  14  Nationality                       651936 non-null  object
#  15  Continent                         651936 non-null  object
#  16  Points (Total)                    651936 non-null  int64
#  17  Points (Ind for each Artist/Nat)  651936 non-null  float64
#  18  id                                651936 non-null  object
#  19  Song URL                          651936 non-null  object
# dtypes: float64(8), int64(2), object(10)
# memory usage: 99.5+ MB

# %% [markdown]
# # Although Title is the same, the ID/Song URL is different for some of the songs and the URL leads to the same song!

# %%
data['Continent'].unique()
# Out:
# array(['Latin-America', 'Asia', 'Anglo-America', 'Europe', 'Africa',
#        'Oceania', 'Unknown'], dtype=object)

# %%
# Nationality and Continent is unknown for 465 rows out of 651,936 rows
data[data['Continent']=="Unknown"]
# Out:
#         Rank                                              Title  \
# 2610     182  Cupid – Twin Ver. (FIFTY FIFTY) – Sped Up Version
# 2909     189  Cupid – Twin Ver. (FIFTY FIFTY) – Sped Up Version
# 3213     196  Cupid – Twin Ver. (FIFTY FIFTY) – Sped Up Version
# 3465     168  Cupid – Twin Ver. (FIFTY FIFTY) – Sped Up Version
# 3501     191            Watch This - ARIZONATEARS Pluggnb Remix
# ...      ...                                                ...
# 518508    66                                             Genius
# 518792    72                                             Genius
# 519074   101                                             Genius
# 519360    88                                             Genius
# 519644    56                                             Genius
#
#                                               Artists        Date  \
# 2610                                     sped up 8282  21/05/2023
# 2909                                     sped up 8282  20/05/2023
# 3213                                     sped up 8282  19/05/2023
# 3465                                     sped up 8282  18/05/2023
# 3501    Lil Uzi Vert, sped up nightcore, ARIZONATEARS  18/05/2023
# ...                                               ...         ...
# 518508                      Sia, Diplo, Labrinth, LSD  08/05/2018
# 518792                      Sia, Diplo, Labrinth, LSD  07/05/2018
# 519074                      Sia, Diplo, Labrinth, LSD  06/05/2018
# 519360                      Sia, Diplo, Labrinth, LSD  05/05/2018
# 519644                      Sia, Diplo, Labrinth, LSD  04/05/2018
#
#         Danceability  Energy  Loudness  Speechiness  Acousticness  \
# 2610           0.737   0.725  -7989.00        0.041         0.417
# 2909           0.737   0.725  -7989.00        0.041         0.417
# 3213           0.737   0.725  -7989.00        0.041         0.417
# 3465           0.737   0.725  -7989.00        0.041         0.417
# 3501           0.686   0.897     -7.18        0.039         0.010
# ...              ...     ...       ...          ...           ...
# 518508         0.622   0.621  -4924.00        0.129         0.086
# 518792         0.622   0.621  -4924.00        0.129         0.086
# 519074         0.622   0.621  -4924.00        0.129         0.086
# 519360         0.622   0.621  -4924.00        0.129         0.086
# 519644         0.622   0.621  -4924.00        0.129         0.086
#
#         Instrumentalness  Valence # of Artist      Artist (Ind.)  \
# 2610               0.001    0.746    Artist 1       sped up 8282
# 2909               0.001    0.746    Artist 1       sped up 8282
# 3213               0.001    0.746    Artist 1       sped up 8282
# 3465               0.001    0.746    Artist 1       sped up 8282
# 3501               0.103    0.355    Artist 2  sped up nightcore
# ...                  ...      ...         ...                ...
# 518508             0.000    0.567    Artist 4                LSD
# 518792             0.000    0.567    Artist 4                LSD
# 519074             0.000    0.567    Artist 4                LSD
# 519360             0.000    0.567    Artist 4                LSD
# 519644             0.000    0.567    Artist 4                LSD
#
#        # of Nationality Nationality Continent  Points (Total)  \
# 2610      Nationality 1     Unknown   Unknown              19
# 2909      Nationality 1     Unknown   Unknown              12
# 3213      Nationality 1     Unknown   Unknown               5
# 3465      Nationality 1     Unknown   Unknown              33
# 3501      Nationality 2     Unknown   Unknown              10
# ...                 ...         ...       ...             ...
# 518508    Nationality 4     Unknown   Unknown             135
# 518792    Nationality 4     Unknown   Unknown             129
# 519074    Nationality 4     Unknown   Unknown             100
# 519360    Nationality 4     Unknown   Unknown             113
# 519644    Nationality 4     Unknown   Unknown             145
#
#         Points (Ind for each Artist/Nat)                      id  \
# 2610                           19.000000  3B228N0GxfUCwPyfNcJxps
# 2909                           12.000000  3B228N0GxfUCwPyfNcJxps
# 3213                            5.000000  3B228N0GxfUCwPyfNcJxps
# 3465                           33.000000  3B228N0GxfUCwPyfNcJxps
# 3501                            3.333333  0FA4wrjDJvJTTU8AepZTup
# ...                                  ...                     ...
# 518508                         34.000000  73F87Sqh6jQWucOOvz1WFx
# 518792                         32.000000  73F87Sqh6jQWucOOvz1WFx
# 519074                         25.000000  73F87Sqh6jQWucOOvz1WFx
# 519360                         28.000000  73F87Sqh6jQWucOOvz1WFx
# 519644                         36.000000  73F87Sqh6jQWucOOvz1WFx
#
#                                                  Song URL
# 2610    https://open.spotify.com/track/3B228N0GxfUCwPy...
# 2909    https://open.spotify.com/track/3B228N0GxfUCwPy...
# 3213    https://open.spotify.com/track/3B228N0GxfUCwPy...
# 3465    https://open.spotify.com/track/3B228N0GxfUCwPy...
# 3501    https://open.spotify.com/track/0FA4wrjDJvJTTU8...
# ...                                                   ...
# 518508  https://open.spotify.com/track/73F87Sqh6jQWucO...
# 518792  https://open.spotify.com/track/73F87Sqh6jQWucO...
# 519074  https://open.spotify.com/track/73F87Sqh6jQWucO...
# 519360  https://open.spotify.com/track/73F87Sqh6jQWucO...
# 519644  https://open.spotify.com/track/73F87Sqh6jQWucO...
#
# [465 rows x 20 columns]

# %% [markdown]
# Check if one artist impacts songs
# Correlation between nationality and some other feature like danceability

# %%
Col_Name = []
Max = []
Min = []
Unique = []
for i in range(data.shape[1]):
    col_name = data.columns[i]
    req_data = data.iloc[:,i]
    max_val = max(req_data)
    min_val = min(req_data)
    no_uni = len(req_data.unique())
    Col_Name.append(col_name)
    Max.append(max_val)
    Min.append(min_val)
    Unique.append(no_uni)

# %%
req_df = pd.DataFrame(list(zip(Col_Name,Max,Min,Unique)),columns=["Col_Name","Max","Min","Unique"])

# %%
req_df
# Out:
#                             Col_Name  \
# 0                               Rank
# 1                              Title
# 2                            Artists
# 3                               Date
# 4                       Danceability
# 5                             Energy
# 6                           Loudness
# 7                        Speechiness
# 8                       Acousticness
# 9                   Instrumentalness
# 10                           Valence
# 11                       # of Artist
# 12                     Artist (Ind.)
# 13                  # of Nationality
# 14                       Nationality
# 15                         Continent
# 16                    Points (Total)
# 17  Points (Ind for each Artist/Nat)
# 18                                id
# 19                          Song URL
#
#                                                   Max  \
# 0                                                 200
# 1                                               美女と野獣
# 2                               Ñengo Flow, Bad Bunny
# 3                                          31/12/2022
# 4                                               0.985
# 5                                               0.996
# 6                                              1509.0
# 7                                               0.966
# 8                                               0.994
# 9                                               0.956
# 10                                              0.982
# 11                                           Artist 9
# 12                                         Ñengo Flow
# 13                                      Nationality 9
# 14                                          Venezuela
# 15                                            Unknown
# 16                                                200
# 17                                              200.0
# 18                             7zxRMhXxJMQCeDDg0rKAVo
# 19  https://open.spotify.com/track/7zxRMhXxJMQCeDD...
#
#                                                   Min  Unique
# 0                                                   1     200
# 1                                          '98 Braves    7457
# 2                                    $NOT, A$AP Rocky    2928
# 3                                          01/01/2017    2336
# 4                                               0.073     739
# 5                                               0.005     860
# 6                                            -34475.0    5331
# 7                                               0.022     532
# 8                                                 0.0     952
# 9                                                 0.0     305
# 10                                              0.026     937
# 11                                           Artist 1       9
# 12                                               $NOT    2208
# 13                                      Nationality 1       9
# 14                                            ALGERIA      74
# 15                                             Africa       7
# 16                                                  1     200
# 17                                                0.2     477
# 18                             000xQL6tZNLJzIrtIgxqSl    9161
# 19  https://open.spotify.com/track/000xQL6tZNLJzIr...    9161
