# %% [markdown]
# # Spotify

# %% [markdown]
# Your task is to analyse the data given to you and explore predictive tasks that could provide the company with insight on some burning questions such as:
#
# 1. What drives cross-regional popularity of music; is it the artist, or something about the song?(explore if artists from certain parts of the world tend to be more popular worldwide)
# 2. Can we figure out which artists or genres are going to be popular in 2024 given the historic data from 2017?
# 3. Does the popularity of a track in one region predict its (upcoming?) popularity in other regions?
# 4. Are there any patterns in what day(s) of the week and/or months experience the most streams?

# %% [markdown]
# 1. Who are the most popular artists (say top 10)?
# 2. Who was the most popular each month?
# 3. Name the songs people dance to the most?
# 4. Is there a relationship between danceability and energy or loundness of the music?
# 5. Does a total number of artists affect the popularity of a song?
# 5. If it does, then can we predict if more artists would make a song more popular
# 6. How does valency affect the popularity of a song. (A high valence song is about happiness, excitement and joy, whereas a low valence song is about sadness, anger or depression.
# 7. Check the mean value of audio features of top 10 songs. Can we predict popularity of songs if they have greater value than the mean value for those features?
#
#
# 1. EDA for each feature
# 2. Release date and popularity date

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
# Importing the data using pd.read_csv
data = pd.read_csv(r'~/anaconda3/Anjali-Spotify/Spotify_Dataset_V3.csv',sep=';')

# %%
data[data["Artists"]=="Kodak Black, NLE Choppa, Jimin, JVKE, Muni Long"]
# Out:
#       Rank                                              Title  \
# 25      17  Angel Pt. 1 (feat. Jimin of BTS, JVKE & Muni L...
# 26      17  Angel Pt. 1 (feat. Jimin of BTS, JVKE & Muni L...
# 27      17  Angel Pt. 1 (feat. Jimin of BTS, JVKE & Muni L...
# 28      17  Angel Pt. 1 (feat. Jimin of BTS, JVKE & Muni L...
# 29      17  Angel Pt. 1 (feat. Jimin of BTS, JVKE & Muni L...
# 322     18  Angel Pt. 1 (feat. Jimin of BTS, JVKE & Muni L...
# 323     18  Angel Pt. 1 (feat. Jimin of BTS, JVKE & Muni L...
# 324     18  Angel Pt. 1 (feat. Jimin of BTS, JVKE & Muni L...
# 325     18  Angel Pt. 1 (feat. Jimin of BTS, JVKE & Muni L...
# 326     18  Angel Pt. 1 (feat. Jimin of BTS, JVKE & Muni L...
# 635     29  Angel Pt. 1 (feat. Jimin of BTS, JVKE & Muni L...
# 636     29  Angel Pt. 1 (feat. Jimin of BTS, JVKE & Muni L...
# 637     29  Angel Pt. 1 (feat. Jimin of BTS, JVKE & Muni L...
# 638     29  Angel Pt. 1 (feat. Jimin of BTS, JVKE & Muni L...
# 639     29  Angel Pt. 1 (feat. Jimin of BTS, JVKE & Muni L...
# 933     26  Angel Pt. 1 (feat. Jimin of BTS, JVKE & Muni L...
# 934     26  Angel Pt. 1 (feat. Jimin of BTS, JVKE & Muni L...
# 935     26  Angel Pt. 1 (feat. Jimin of BTS, JVKE & Muni L...
# 936     26  Angel Pt. 1 (feat. Jimin of BTS, JVKE & Muni L...
# 937     26  Angel Pt. 1 (feat. Jimin of BTS, JVKE & Muni L...
# 1206    12  Angel Pt. 1 (feat. Jimin of BTS, JVKE & Muni L...
# 2364  https://open.spotify.com/track/1vvcEHQdaUTvWt0...
# 2648  https://open.spotify.com/track/1vvcEHQdaUTvWt0...
# 2649  https://open.spotify.com/track/1vvcEHQdaUTvWt0...
# 2650  https://open.spotify.com/track/1vvcEHQdaUTvWt0...
# 2651  https://open.spotify.com/track/1vvcEHQdaUTvWt0...
# 2652  https://open.spotify.com/track/1vvcEHQdaUTvWt0...
# 2939  https://open.spotify.com/track/1vvcEHQdaUTvWt0...
# 2940  https://open.spotify.com/track/1vvcEHQdaUTvWt0...
# 2941  https://open.spotify.com/track/1vvcEHQdaUTvWt0...
# 2942  https://open.spotify.com/track/1vvcEHQdaUTvWt0...
# 2943  https://open.spotify.com/track/1vvcEHQdaUTvWt0...
# 3259  https://open.spotify.com/track/1XUXrNFoi9ixlH3...
# 3260  https://open.spotify.com/track/1XUXrNFoi9ixlH3...
# 3261  https://open.spotify.com/track/1XUXrNFoi9ixlH3...
# 3262  https://open.spotify.com/track/1XUXrNFoi9ixlH3...
# 3263  https://open.spotify.com/track/1XUXrNFoi9ixlH3...

# %%
# Checking the data head - a glimpse of the data
data.head();

# %%
# Getting information about each column of the data 
# Checking for null values and data types
# Checking the shape of the data - 651936x20
data.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 651936 entries, 0 to 651935
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Rank                              651936 non-null  int64
#  1   Title                             651936 non-null  object
#  2   Artists                           651936 non-null  object
#  3   Date                              651936 non-null  object
#  4   Danceability                      651936 non-null  float64
#  5   Energy                            651936 non-null  float64
#  6   Loudness                          651936 non-null  float64
#  7   Speechiness                       651936 non-null  float64
#  8   Acousticness                      651936 non-null  float64
#  9   Instrumentalness                  651936 non-null  float64
#  10  Valence                           651936 non-null  float64
#  11  # of Artist                       651936 non-null  object
#  12  Artist (Ind.)                     651936 non-null  object
#  13  # of Nationality                  651936 non-null  object
#  14  Nationality                       651936 non-null  object
#  15  Continent                         651936 non-null  object
#  16  Points (Total)                    651936 non-null  int64
#  17  Points (Ind for each Artist/Nat)  651936 non-null  float64
#  18  id                                651936 non-null  object
#  19  Song URL                          651936 non-null  object
# dtypes: float64(8), int64(2), object(10)
# memory usage: 99.5+ MB

# %% [markdown]
# ### Data Cleaning and Pre-Processing

# %%
# Checking for duplicates
data[data.duplicated()];
# No duplicates found

# %% [markdown]
# Genres to consider:
#
# don't care about the artist, title, date, rank and number of artists. I don't think these would have a meaningful connection with the genre.
#
# Danceability-Energy-Loudness-Speechiness-Acousticness-Instrumentalness-Valence
#
# _Rock_ - LessDanceable-ModeratelyEnergetic-ModeratelyLoud-ModeratelySpeechy-MoreAcoustic-HighlyInstrumental-ModeratelyValent
#
# _Jazz_ - LessDanceable-LessEnergetic-ModeratelyLoud-LessSpeechy-ModeratelyAcoustic-HighlyInstrumental-ModeratelyValent
#
# _Sad_ - LessDanceable-LessEnergetic-LessLoud-ModeratelySpeechy-LessAcoustic-LessInstrumental-LowValency
#
# _Elec_ - VeryDanceable-VeryEnergetic-VeryLoud-ModerateToHighSpeech-MoreAcoustic-HighlyInstrumental-HighValencey
#
# _Rap_ - ModeratelyDanceable-VeryEnergetic-ModeratelyLoud-VerySpeechy-MoreAcoustic-ModeratelyInstrumental-ModerateValency

# %%
column = 'Loudness'
data[column] = (data[column]-data[column].min())/(data[column].max() - data[column].min())

# %%
data.describe()
# Out:
#                 Rank   Danceability         Energy       Loudness  \
# count  651936.000000  651936.000000  651936.000000  651936.000000
# mean      100.407782       0.697730       0.652049       0.810898
# std        57.406664       0.133186       0.155684       0.077403
# min         1.000000       0.073000       0.005000       0.000000
# 25%        51.000000       0.617000       0.549000       0.768397
# 50%       100.000000       0.719000       0.671000       0.813389
# 75%       150.000000       0.793000       0.771000       0.850100
# max       200.000000       0.985000       0.996000       1.000000
#
#          Speechiness   Acousticness  Instrumentalness        Valence  \
# count  651936.000000  651936.000000     651936.000000  651936.000000
# mean        0.109946       0.230694          0.007647       0.523134
# std         0.096841       0.230710          0.054724       0.223926
# min         0.022000       0.000000          0.000000       0.026000
# 25%         0.045000       0.048000          0.000000       0.356000
# 50%         0.068000       0.152000          0.000000       0.521000
# 75%         0.136000       0.349000          0.000000       0.696000
# max         0.966000       0.994000          0.956000       0.982000
#
#        Points (Total)  Points (Ind for each Artist/Nat)
# count   651936.000000                     651936.000000
# mean       100.592218                         72.391141
# std         57.406664                         54.227892
# min          1.000000                          0.200000
# 25%         51.000000                         28.000000
# 50%        101.000000                         60.000000
# 75%        150.000000                        104.000000
# max        200.000000                        200.000000

# %%
#Unable to use the "Instrumentalness" column because most values are 0
edm_condition = (
    (data['Danceability'] >= 0.49) &
    (data['Energy'] >= 0.5) &
    (data['Loudness'] >= 0.6) &
    (data['Valence'] >= 0.25))

hip_hop_condition = (
    (data['Danceability'] >= 0.5) &
    (data['Energy'] < 0.7) &
    (data['Loudness'] >= 0.5) &
    (data['Speechiness'] >= 0.07))

rap_condition = (
    (data['Speechiness'] >= 0.3))

pop_condition = (
    (data['Danceability'] < 0.7) &
    (data['Loudness'] >= 0.4))

rb_condition = (
    (data['Loudness'] >= 0.75) &
    (data['Speechiness'] >= 0.1))

latin_condition = (
    (data['Nationality'].str.contains('Brazil|Colombia|Dominican Republic|Puerto Rico')))

# Create a 'Genre' column based on the conditions
data['Genre'] = 'Other'  # Default to 'Other' genre
data.loc[edm_condition, 'Genre'] = 'EDM'
data.loc[hip_hop_condition, 'Genre'] = 'Hip-Hop'
data.loc[rap_condition, 'Genre'] = 'Rap'
data.loc[pop_condition, 'Genre'] = 'Pop'
data.loc[rb_condition, 'Genre'] = 'R&B'
data.loc[latin_condition, 'Genre'] = 'Latin'

# %%
data["Genre"].value_counts()
# Out:
# Pop        207810
# R&B        131077
# Latin      129304
# EDM        109273
# Hip-Hop     43147
# Other       20974
# Rap         10351
# Name: Genre, dtype: int64

# %%
# Removing the '# artists', 'Artist (Ind.)', '# nationality', 'Nationality',
# 'Points (Ind for each Artist/Nat)' and 'Continent', 'id' and 'song url','Points' columns 
# to get a single entry for each song. 

# We are removing the number of artists rows because it creates partial duplicated rows
# which might affect the result.
data_wt_art = data.drop(columns=['# of Artist','Artist (Ind.)','# of Nationality',
                                'Nationality','Continent','id','Song URL',
                                'Points (Ind for each Artist/Nat)','Points (Total)'])

data_wt_art = data_wt_art.drop_duplicates(keep='first')
data_wt_art = data_wt_art.reset_index(drop=True)

# %% [markdown]
# ### Exploratory Data Analysis and Visualization

# %% [markdown]
# - `danceability` : Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
# - `energy` : Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy.
# - `loudness` : The overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks.
# - `speechiness` : Speechiness detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value.
# - `acousticness` : A confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic.
# - `instrumentalness` : Predicts whether a track contains no vocals. The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content.
# - `valence` : A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive, while tracks with low valence sound more negative.

# %% [markdown]
# **Correlation between audio features**

# %%
#corr = data_wt_art[['Danceability','Energy','Loudness','Speechiness','Acousticness', 
#                  'Instrumentalness','Valence']].corr()

#mask = np.triu(np.ones_like(corr, dtype=bool))
#cmap = sns.diverging_palette(230, 20, as_cmap=True)

#plt.title('Correlation between the audio features')
#sns.heatmap(corr,cmap=cmap,annot=True);

corr = data_wt_art[['Danceability', 
                  'Energy', 
                  'Loudness', 
                  'Speechiness', 
                  'Acousticness', 
                  'Instrumentalness',
                  'Valence']].corr()
cmap = sns.diverging_palette(230, 20, as_cmap=True)
corr.style.background_gradient(cmap=cmap)
# Out:
# <style type="text/css">
# #T_59f4f_row0_col0, #T_59f4f_row1_col1, #T_59f4f_row2_col2, #T_59f4f_row3_col3, #T_59f4f_row4_col4, #T_59f4f_row5_col5, #T_59f4f_row6_col6 {
#   background-color: #c3553a;
#   color: #f1f1f1;
# }
# #T_59f4f_row0_col1, #T_59f4f_row6_col2 {
#   background-color: #dae3e8;
#   color: #000000;
# }
# #T_59f4f_row0_col2 {
#   background-color: #c1d3db;
#   color: #000000;
# }
# #T_59f4f_row0_col3 {
#   background-color: #95b6c6;
#   color: #000000;
# }
# #T_59f4f_row0_col4 {
#   background-color: #82a9bc;
#   color: #f1f1f1;
# }
# #T_59f4f_row0_col5 {
#   background-color: #5e92ab;
#   color: #f1f1f1;
# }
# #T_59f4f_row0_col6 {
#   background-color: #e2e8ec;
#   color: #000000;
# }
# #T_59f4f_row1_col0 {
#   background-color: #abc4d0;
#   color: #000000;
# }
# #T_59f4f_row1_col2 {
#   background-color: #e4c2ba;
#   color: #000000;
# }
# #T_59f4f_row1_col3 {
#   background-color: #4e87a2;
#   color: #f1f1f1;
# }
# #T_59f4f_row1_col4, #T_59f4f_row2_col5, #T_59f4f_row4_col0, #T_59f4f_row4_col1, #T_59f4f_row4_col2, #T_59f4f_row4_col3, #T_59f4f_row4_col6 {
#   background-color: #407e9c;
#   color: #f1f1f1;
# }
# #T_59f4f_row1_col5 {
#   background-color: #578da7;
#   color: #f1f1f1;
# }
# #T_59f4f_row1_col6 {
#   background-color: #e6ebee;
#   color: #000000;
# }
# #T_59f4f_row2_col0 {
#   background-color: #b6cbd6;
#   color: #000000;
# }
# #T_59f4f_row2_col1 {
#   background-color: #dfb1a6;
#   color: #000000;
# }
# #T_59f4f_row2_col3 {
#   background-color: #43809d;
#   color: #f1f1f1;
# }
# #T_59f4f_row2_col4 {
#   background-color: #76a1b6;
#   color: #f1f1f1;
# }
# #T_59f4f_row2_col6 {
#   background-color: #b9cdd7;
#   color: #000000;
# }
# #T_59f4f_row3_col0 {
#   background-color: #bed1da;
#   color: #000000;
# }
# #T_59f4f_row3_col1 {
#   background-color: #b7ccd7;
#   color: #000000;
# }
# #T_59f4f_row3_col2 {
#   background-color: #84aabd;
#   color: #f1f1f1;
# }
# #T_59f4f_row3_col4 {
#   background-color: #aec6d2;
#   color: #000000;
# }
# #T_59f4f_row3_col5 {
#   background-color: #6999b0;
#   color: #f1f1f1;
# }
# #T_59f4f_row3_col6 {
#   background-color: #6797af;
#   color: #f1f1f1;
# }
# #T_59f4f_row4_col5 {
#   background-color: #81a9bc;
#   color: #f1f1f1;
# }
# #T_59f4f_row5_col0 {
#   background-color: #73a0b5;
#   color: #f1f1f1;
# }
# #T_59f4f_row5_col1 {
#   background-color: #a8c2cf;
#   color: #000000;
# }
# #T_59f4f_row5_col2 {
#   background-color: #6596ae;
#   color: #f1f1f1;
# }
# #T_59f4f_row5_col3 {
#   background-color: #4b85a1;
#   color: #f1f1f1;
# }
# #T_59f4f_row5_col4 {
#   background-color: #c6d6de;
#   color: #000000;
# }
# #T_59f4f_row5_col6 {
#   background-color: #44819e;
#   color: #f1f1f1;
# }
# #T_59f4f_row6_col0 {
#   background-color: #f1edec;
#   color: #000000;
# }
# #T_59f4f_row6_col1 {
#   background-color: #e8cfc8;
#   color: #000000;
# }
# #T_59f4f_row6_col3 {
#   background-color: #558ca6;
#   color: #f1f1f1;
# }
# #T_59f4f_row6_col4 {
#   background-color: #a0bdcb;
#   color: #000000;
# }
# #T_59f4f_row6_col5 {
#   background-color: #5189a4;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_59f4f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_59f4f_level0_col0" class="col_heading level0 col0" >Danceability</th>
#       <th id="T_59f4f_level0_col1" class="col_heading level0 col1" >Energy</th>
#       <th id="T_59f4f_level0_col2" class="col_heading level0 col2" >Loudness</th>
#       <th id="T_59f4f_level0_col3" class="col_heading level0 col3" >Speechiness</th>
#       <th id="T_59f4f_level0_col4" class="col_heading level0 col4" >Acousticness</th>
#       <th id="T_59f4f_level0_col5" class="col_heading level0 col5" >Instrumentalness</th>
#       <th id="T_59f4f_level0_col6" class="col_heading level0 col6" >Valence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T
#       <td id="T_59f4f_row4_col5" class="data row4 col5" >0.051769</td>
#       <td id="T_59f4f_row4_col6" class="data row4 col6" >-0.119541</td>
#     </tr>
#     <tr>
#       <th id="T_59f4f_level0_row5" class="row_heading level0 row5" >Instrumentalness</th>
#       <td id="T_59f4f_row5_col0" class="data row5 col0" >-0.061475</td>
#       <td id="T_59f4f_row5_col1" class="data row5 col1" >-0.080736</td>
#       <td id="T_59f4f_row5_col2" class="data row5 col2" >-0.162202</td>
#       <td id="T_59f4f_row5_col3" class="data row5 col3" >-0.023808</td>
#       <td id="T_59f4f_row5_col4" class="data row5 col4" >0.051769</td>
#       <td id="T_59f4f_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_59f4f_row5_col6" class="data row5 col6" >-0.105970</td>
#     </tr>
#     <tr>
#       <th id="T_59f4f_level0_row6" class="row_heading level0 row6" >Valence</th>
#       <td id="T_59f4f_row6_col0" class="data row6 col0" >0.394758</td>
#       <td id="T_59f4f_row6_col1" class="data row6 col1" >0.405715</td>
#       <td id="T_59f4f_row6_col2" class="data row6 col2" >0.265152</td>
#       <td id="T_59f4f_row6_col3" class="data row6 col3" >0.005609</td>
#       <td id="T_59f4f_row6_col4" class="data row6 col4" >-0.119541</td>
#       <td id="T_59f4f_row6_col5" class="data row6 col5" >-0.105970</td>
#       <td id="T_59f4f_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Here, we can observe that
# 1. Danceability ~ + Valence
# 2. Energy ~ + Loudness
# 3. Energy ~ - Acousticness
# 4. Energy ~ + Valence
# 5. Loudness ~ - Acousticness
# 6. Loudness ~ + Valence

# %%
x1_feature = 'Energy'
y1_feature = 'Acousticness'

plt.figure(figsize=(8,4))
plt.subplot(1,2,1)
sns.scatterplot(x=x1_feature, y=y1_feature, data=data_wt_art, alpha=0.7)
plt.xlabel(x_feature)
plt.ylabel(y_feature)
plt.title(f'{y1_feature} vs. {x1_feature}')

x2_feature = 'Energy'
y2_feature = 'Loudness'

plt.subplot(1,2,2)
sns.scatterplot(x=x2_feature, y=y2_feature, data=data_wt_art, alpha=0.7)
plt.xlabel(x_feature)
plt.ylabel(y_feature)
plt.title(f'{y2_feature} vs. {x2_feature}')

plt.subplots_adjust(wspace=1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 7
#       5 plt.subplot(1,2,1)
#       6 sns.scatterplot(x=x1_feature, y=y1_feature, data=data_wt_art, alpha=0.7)
# ----> 7 plt.xlabel(x_feature)
#       8 plt.ylabel(y_feature)
#       9 plt.title(f'{y1_feature} vs. {x1_feature}')
#
# NameError: name 'x_feature' is not defined

# %% [markdown]
# **Percentage of each Genre**

# %%
#data_wt_art["Genre"].value_counts().plot(kind="pie")

plt.figure(figsize=(7,7))
plt.pie(
    x=data_wt_art["Genre"].value_counts(), 
    labels=data_wt_art["Genre"].unique(),
    autopct='%1.2f%%',
    labeldistance=0.75,
    pctdistance=0.62,
    colors=sns.color_palette('Pastel1'))

# Add Title 
plt.title(label="Percentage of Each Genre",weight='bold')

hole = plt.Circle((0, 0), 0.5, facecolor='white')
plt.gcf().gca().add_artist(hole)

plt.show()

# %% [markdown]
# ### Answering Questions

# %% [markdown]
# **What are the most popular songs?**

# %%
# Here we get the frequency for each Song being in the top 200 everyday
title_cnt = data_wt_art.groupby('Title').count()
# We find out the 15 most frequently occuring songs in top 200 playlist
title_freq = title_cnt['Rank'].nlargest(15)

# %%
# Plotting these songs with their frequencies

with sns.axes_style('white'):
    plt.title("15 most frequent songs on Spotify's top 200 playlist",weight='bold')
    plt.xlabel("Frequency")
    sns.barplot(x=title_freq.values, y=title_freq.index, palette='GnBu_r');

# %% [markdown]
# **Audio Features of one of the most popular songs**

# %%
song_name = "Last Christmas"
labels = np.array(['Acousticness','Danceability','Instrumentalness','Energy','Valence'])
song_data = data_wt_art[data_wt_art["Title"]==song_name].iloc[0:1]
song = song_data.loc[:, labels].values.squeeze()

angles = np.linspace(0, 2*np.pi, len(labels), endpoint=False)
song = np.concatenate((song,[song[0]]))
angles = np.concatenate((angles,[angles[0]]))

#Radar Chart
fig=plt.show()
ax=plt.subplot(111, polar=True)
ax.plot(angles, song, linewidth=1.5,color="skyblue")
ax.fill(angles, song, alpha=0.3,color="red")
ax.set_thetagrids((angles * 180/np.pi)[0:5], labels)
ax.set_title('Audio Features of : ' + song_name,weight='bold')
ax.grid(True)

# %%
data_wt_art_scaled = data_wt_art.copy()
column = 'Loudness'
data_wt_art_scaled[column] = (data_wt_art_scaled[column]-data_wt_art_scaled[column].min()
                             )/(data_wt_art_scaled[column].max() - data_wt_art_scaled[column].min())
song_name = "Last Christmas"
labels = np.array(['Acousticness','Danceability',
                   'Instrumentalness','Loudness','Energy','Valence'])
song_data = data_wt_art_scaled[data_wt_art_scaled["Title"]==song_name].iloc[0:1]
song = song_data.loc[:, labels].values.squeeze()

angles = np.linspace(0, 2*np.pi, len(labels), endpoint=False)
song = np.concatenate((song,[song[0]]))
angles = np.concatenate((angles,[angles[0]]))

#Radar Chart
fig=plt.show()
ax=plt.subplot(111, polar=True)
ax.plot(angles, song, linewidth=1.5,color="skyblue")
ax.fill(angles, song, alpha=0.3,color="red")
ax.set_thetagrids((angles * 180/np.pi)[0:6], labels)
ax.set_title('Audio Features of : ' + song_name,weight='bold')
ax.grid(True)

# %% [markdown]
# **Songs to which people dance the most**

# %%
title_max = data_wt_art.groupby('Title').max().reset_index()

most_danceable = title_max.sort_values('Danceability', ascending=False).head(10)

with sns.axes_style('white'):
    plt.title('10 Most Danceable Songs',weight='bold')
    sns.barplot(x=most_danceable.Danceability, y=most_danceable.Title, palette='mako')
    plt.xlabel('Danceability')
    plt.ylabel('Title');

# %% [markdown]
# **Song trends over-time**

# %%
data_wt_art['MonthYear'] = pd.to_datetime(data_wt_art['Date']).dt.to_period('M')
data_wt_art["MonthYear"] = data_wt_art["MonthYear"].astype(str)

date_data = data_wt_art.groupby('MonthYear')[["Danceability", "Energy", "Speechiness",
                                               "Acousticness", "Instrumentalness",
                                               "Valence"]].mean().reset_index()

date_data = date_data.melt(id_vars='MonthYear')

plt.figure(figsize=(16, 8))
plt.title('Song Trends Over Time')
sns.lineplot(x='MonthYear', y='value', hue='variable', data=date_data)
plt.xticks(range(0,84,12))
plt.show()

# %%
data['Continent'].unique()
# Out:
# array(['Latin-America', 'Asia', 'Anglo-America', 'Europe', 'Africa',
#        'Oceania', 'Unknown'], dtype=object)

# %%
# Nationality and Continent is unknown for 465 rows out of 651,936 rows
data[data['Continent']=="Unknown"]
# Out:
#         Rank                                              Title  \
# 2610     182  Cupid – Twin Ver. (FIFTY FIFTY) – Sped Up Version
# 2909     189  Cupid – Twin Ver. (FIFTY FIFTY) – Sped Up Version
# 3213     196  Cupid – Twin Ver. (FIFTY FIFTY) – Sped Up Version
# 3465     168  Cupid – Twin Ver. (FIFTY FIFTY) – Sped Up Version
# 3501     191            Watch This - ARIZONATEARS Pluggnb Remix
# ...      ...                                                ...
# 518508    66                                             Genius
# 518792    72                                             Genius
# 519074   101                                             Genius
# 519360    88                                             Genius
# 519644    56                                             Genius
#
#                                               Artists        Date  \
# 2610                                     sped up 8282  21/05/2023
# 2909                                     sped up 8282  20/05/2023
# 3213                                     sped up 8282  19/05/2023
# 3465                                     sped up 8282  18/05/2023
# 3501    Lil Uzi Vert, sped up nightcore, ARIZONATEARS  18/05/2023
# ...                                               ...         ...
# 518508                      Sia, Diplo, Labrinth, LSD  08/05/2018
# 518792                      Sia, Diplo, Labrinth, LSD  07/05/2018
# 519074                      Sia, Diplo, Labrinth, LSD  06/05/2018
# 519360                      Sia, Diplo, Labrinth, LSD  05/05/2018
# 519644                      Sia, Diplo, Labrinth, LSD  04/05/2018
#
#         Danceability  Energy  Loudness  Speechiness  Acousticness  \
# 2610           0.737   0.725  -7989.00        0.041         0.417
# 2909           0.737   0.725  -7989.00        0.041         0.417
# 3213           0.737   0.725  -7989.00        0.041         0.417
# 3465           0.737   0.725  -7989.00        0.041         0.417
# 3501           0.686   0.897     -7.18        0.039         0.010
# ...              ...     ...       ...          ...           ...
# 518508         0.622   0.621  -4924.00        0.129         0.086
# 518792         0.622   0.621  -4924.00        0.129         0.086
# 519074         0.622   0.621  -4924.00        0.129         0.086
# 519360         0.622   0.621  -4924.00        0.129         0.086
# 519644         0.622   0.621  -4924.00        0.129         0.086
#
#         Instrumentalness  Valence # of Artist      Artist (Ind.)  \
# 2610               0.001    0.746    Artist 1       sped up 8282
# 2909               0.001    0.746    Artist 1       sped up 8282
# 3213               0.001    0.746    Artist 1       sped up 8282
# 3465               0.001    0.746    Artist 1       sped up 8282
# 3501               0.103    0.355    Artist 2  sped up nightcore
# ...                  ...      ...         ...                ...
# 518508             0.000    0.567    Artist 4                LSD
# 518792             0.000    0.567    Artist 4                LSD
# 519074             0.000    0.567    Artist 4                LSD
# 519360             0.000    0.567    Artist 4                LSD
# 519644             0.000    0.567    Artist 4                LSD
#
#        # of Nationality Nationality Continent  Points (Total)  \
# 2610      Nationality 1     Unknown   Unknown              19
# 2909      Nationality 1     Unknown   Unknown              12
# 3213      Nationality 1     Unknown   Unknown               5
# 3465      Nationality 1     Unknown   Unknown              33
# 3501      Nationality 2     Unknown   Unknown              10
# ...                 ...         ...       ...             ...
# 518508    Nationality 4     Unknown   Unknown             135
# 518792    Nationality 4     Unknown   Unknown             129
# 519074    Nationality 4     Unknown   Unknown             100
# 519360    Nationality 4     Unknown   Unknown             113
# 519644    Nationality 4     Unknown   Unknown             145
#
#         Points (Ind for each Artist/Nat)                      id  \
# 2610                           19.000000  3B228N0GxfUCwPyfNcJxps
# 2909                           12.000000  3B228N0GxfUCwPyfNcJxps
# 3213                            5.000000  3B228N0GxfUCwPyfNcJxps
# 3465                           33.000000  3B228N0GxfUCwPyfNcJxps
# 3501                            3.333333  0FA4wrjDJvJTTU8AepZTup
# ...                                  ...                     ...
# 518508                         34.000000  73F87Sqh6jQWucOOvz1WFx
# 518792                         32.000000  73F87Sqh6jQWucOOvz1WFx
# 519074                         25.000000  73F87Sqh6jQWucOOvz1WFx
# 519360                         28.000000  73F87Sqh6jQWucOOvz1WFx
# 519644                         36.000000  73F87Sqh6jQWucOOvz1WFx
#
#                                                  Song URL
# 2610    https://open.spotify.com/track/3B228N0GxfUCwPy...
# 2909    https://open.spotify.com/track/3B228N0GxfUCwPy...
# 3213    https://open.spotify.com/track/3B228N0GxfUCwPy...
# 3465    https://open.spotify.com/track/3B228N0GxfUCwPy...
# 3501    https://open.spotify.com/track/0FA4wrjDJvJTTU8...
# ...                                                   ...
# 518508  https://open.spotify.com/track/73F87Sqh6jQWucO...
# 518792  https://open.spotify.com/track/73F87Sqh6jQWucO...
# 519074  https://open.spotify.com/track/73F87Sqh6jQWucO...
# 519360  https://open.spotify.com/track/73F87Sqh6jQWucO...
# 519644  https://open.spotify.com/track/73F87Sqh6jQWucO...
#
# [465 rows x 20 columns]

# %% [markdown]
# Check if one artist impacts songs
# Correlation between nationality and some other feature like danceability

# %%
Col_Name = []
Max = []
Min = []
Unique = []
for i in range(data.shape[1]):
    col_name = data.columns[i]
    req_data = data.iloc[:,i]
    max_val = max(req_data)
    min_val = min(req_data)
    no_uni = len(req_data.unique())
    Col_Name.append(col_name)
    Max.append(max_val)
    Min.append(min_val)
    Unique.append(no_uni)

# %%
req_df = pd.DataFrame(list(zip(Col_Name,Max,Min,Unique)),columns=["Col_Name","Max","Min","Unique"])

# %%
req_df
#req_df.describe()
# Out:
#                             Col_Name  \
# 0                               Rank
# 1                              Title
# 2                            Artists
# 3                               Date
# 4                       Danceability
# 5                             Energy
# 6                           Loudness
# 7                        Speechiness
# 8                       Acousticness
# 9                   Instrumentalness
# 10                           Valence
# 11                       # of Artist
# 12                     Artist (Ind.)
# 13                  # of Nationality
# 14                       Nationality
# 15                         Continent
# 16                    Points (Total)
# 17  Points (Ind for each Artist/Nat)
# 18                                id
# 19                          Song URL
#
#                                                   Max  \
# 0                                                 200
# 1                                               美女と野獣
# 2                               Ñengo Flow, Bad Bunny
# 3                                          31/12/2022
# 4                                               0.985
# 5                                               0.996
# 6                                              1509.0
# 7                                               0.966
# 8                                               0.994
# 9                                               0.956
# 10                                              0.982
# 11                                           Artist 9
# 12                                         Ñengo Flow
# 13                                      Nationality 9
# 14                                          Venezuela
# 15                                            Unknown
# 16                                                200
# 17                                              200.0
# 18                             7zxRMhXxJMQCeDDg0rKAVo
# 19  https://open.spotify.com/track/7zxRMhXxJMQCeDD...
#
#                                                   Min  Unique
# 0                                                   1     200
# 1                                          '98 Braves    7457
# 2                                    $NOT, A$AP Rocky    2928
# 3                                          01/01/2017    2336
# 4                                               0.073     739
# 5                                               0.005     860
# 6                                            -34475.0    5331
# 7                                               0.022     532
# 8                                                 0.0     952
# 9                                                 0.0     305
# 10                                              0.026     937
# 11                                           Artist 1       9
# 12                                               $NOT    2208
# 13                                      Nationality 1       9
# 14                                            ALGERIA      74
# 15                                             Africa       7
# 16                                                  1     200
# 17                                                0.2     477
# 18                             000xQL6tZNLJzIrtIgxqSl    9161
# 19  https://open.spotify.com/track/000xQL6tZNLJzIr...    9161

# %%
data[data["Energy"]==0.996]
# Out:
#         Rank                            Title           Artists        Date  \
# 262913   136              Genocidal Humanoidz  System Of A Down  06/11/2020
# 332382   129  It's A Raid (feat. Post Malone)     Ozzy Osbourne  21/02/2020
#
#         Danceability  Energy  Loudness  Speechiness  Acousticness  \
# 262913         0.566   0.996 -2086.000        0.213         0.013
# 332382         0.472   0.996    -0.578        0.160         0.007
#
#         Instrumentalness  Valence # of Artist     Artist (Ind.)  \
# 262913               0.0    0.098    Artist 1  System Of A Down
# 332382               0.0    0.114    Artist 1     Ozzy Osbourne
#
#        # of Nationality     Nationality      Continent  Points (Total)  \
# 262913    Nationality 1   United States  Anglo-America              65
# 332382    Nationality 1  United Kingdom         Europe              72
#
#         Points (Ind for each Artist/Nat)                      id  \
# 262913                              65.0  3Sg3bOiD0kE4D5DcXk48Ds
# 332382                              72.0  4CEFxa53bQl45kF3Fq6CeD
#
#                                                  Song URL
# 262913  https://open.spotify.com/track/3Sg3bOiD0kE4D5D...
# 332382  https://open.spotify.com/track/4CEFxa53bQl45kF...

# %% [markdown]
# Genres to consider:
#
# don't care about the artist, title, date, rank and number of artists. I don't think these would have a meaningful connection with the genre.
#
# Danceability-Energy-Loudness-Speechiness-Acousticness-Instrumentalness-Valence
#
# _Rock_ - LessDanceable-ModeratelyEnergetic-ModeratelyLoud-ModeratelySpeechy-MoreAcoustic-HighlyInstrumental-ModeratelyValent
#
# _Jazz_ - LessDanceable-LessEnergetic-ModeratelyLoud-LessSpeechy-ModeratelyAcoustic-HighlyInstrumental-ModeratelyValent
#
# _Sad_ - LessDanceable-LessEnergetic-LessLoud-ModeratelySpeechy-LessAcoustic-LessInstrumental-LowValency
#
# _Elec_ - VeryDanceable-VeryEnergetic-VeryLoud-ModerateToHighSpeech-MoreAcoustic-HighlyInstrumental-HighValencey
#
# _Rap_ - ModeratelyDanceable-VeryEnergetic-ModeratelyLoud-VerySpeechy-MoreAcoustic-ModeratelyInstrumental-ModerateValency
